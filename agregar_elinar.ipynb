# %% [markdown]
# # Agregar o eliminar datos
#
# **Borrar fila y columnas**
# - El metodo head(n=2): muestra la cabeza de dataframe en este caso indicamos que muestre 2 elementos
#
# - El metodo drop(labels, axis): Elimina una fila o columna indicada en axis y para eliminar se espeficica la columna a eliminar con el parametro labels, y con el parametro inplace=True: Hacemos que se elimine definitivamente del array
#
# - del de python: del df_books["Price"]: Este comando nos ayuda a eliminar la columna Price
# - df_books.drop(labels=0, axis=0).head(2): borra la primera fila del array
#
# **Agregar filas y columnas**
# Podemos agregar columnas de la siguiente forma:
# ```python
# import numpy as np
# import pandas as pd
# df_books["nuevacolum"]=np.nan
# ```
#
# Podemos agregar filas de la siguiente manera:
# ```python
# df_books.append(df_books)
# ```
# ```python
# df_books.loc[551,:]=np.nan
# ```

# %%
import pandas as pd
import numpy as np

# %%
df_books=pd.read_csv(filepath_or_buffer="./data/bestsellers_data.csv", sep=",", header=0)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.head(n=2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
df_books.drop(labels="Genre", axis=1, inplace=True)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
df_books=df_books.drop(labels="Year", axis=1)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22

# %%
del df_books["Price"]

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350
# 1              11/22/63: A Novel  Stephen King          4.6     2052

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews
# 0                    JJ Smith          4.7    17350
# 1                Stephen King          4.6     2052
# 2          Jordan B. Peterson          4.7    18979
# 3               George Orwell          4.7    21424
# ...

# %%
df_books.drop(labels=0, axis=0).head(2)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews
# 1     2052
# 2    18979

# %%
from turtle import st


df_books.drop(labels=np.arange(start=0, stop=10) , axis=0).head(10)
# Out:
#                                                  Name  \
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# 16  Adult Coloring Book: Stress Relieving Animal D...
# 17     Adult Coloring Book: Stress Relieving Patterns
# 18  Adult Coloring Books: A Coloring Book for Adul...
# 19                                 Alexander Hamilton
#
#                          Author  User Rating  Reviews
# 10              Fredrik Backman          4.6    23848
# 11             Larry Schweikart          4.6      460
# 12                Jaycee Dugard          4.6     4149
# 13            Madeleine L'Engle          4.5     5153
# 14                 Steve Harvey          4.6     5013
# ...

# %%
df_books["nuevacolum"]=np.nan

# %%
df_books.head(10)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
# 9                          A Man Called Ove: A Novel
#
#                      Author  User Rating  Reviews  nuevacolum
# 0                  JJ Smith          4.7    17350         NaN
# 1              Stephen King          4.6     2052         NaN
# 2        Jordan B. Peterson          4.7    18979         NaN
# 3             George Orwell          4.7    21424         NaN
# 4  National Geographic Kids          4.8     7665         NaN
# ...

# %%
data=np.arange(start=0, stop=df_books.shape[0])

# %%
df_books["Rango"]=data
df_books.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  nuevacolum  Rango
# 0                  JJ Smith          4.7    17350         NaN      0
# 1              Stephen King          4.6     2052         NaN      1
# 2        Jordan B. Peterson          4.7    18979         NaN      2
# 3             George Orwell          4.7    21424         NaN      3
# 4  National Geographic Kids          4.8     7665         NaN      4

# %%
df_books.append(df_books)
# Out:
# /tmp/ipykernel_22929/1991810635.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_books.append(df_books)
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  nuevacolum  Rango
# ...

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  nuevacolum  Rango
# 0                    JJ Smith          4.7    17350         NaN      0
# 1                Stephen King          4.6     2052         NaN      1
# 2          Jordan B. Peterson          4.7    18979         NaN      2
# ...

# %%
df_books.loc[551,:]=np.nan

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 551                                                NaN
#
#                        Author  User Rating  Reviews  nuevacolum  Rango
# 0                    JJ Smith          4.7  17350.0         NaN    0.0
# 1                Stephen King          4.6   2052.0         NaN    1.0
# 2          Jordan B. Peterson          4.7  18979.0         NaN    2.0
# ...
